# %%
# Import Dependencies
import pandas as pd
import numpy as np

# File to load
clvd_to_load = "../Resources/processed_cleveland.csv"
va_to_load = "../Resources/processed_va.csv"
hgrn_to_load = "../Resources/reprocessed_hungarian.csv"

# Read the Data
clvd_df = pd.read_csv(clvd_to_load)
va_df = pd.read_csv(va_to_load)
hgrn_df = pd.read_csv(hgrn_to_load)

# %%
clvd_df.head(10)
# Out:
#    Age  Sex   Chest Pain (cp)  Resting Blood Pressure (trestbps)  \
# 0   63    1                 1                                145
# 1   67    1                 4                                160
# 2   67    1                 4                                120
# 3   37    1                 3                                130
# 4   41    0                 2                                130
# 5   56    1                 2                                120
# 6   62    0                 4                                140
# 7   57    0                 4                                120
# 8   63    1                 4                                130
# 9   53    1                 4                                140
#
#    Serum Cholestoral (Chol)  Fasting Blood Sugar (fbs)  \
# 0                       233                          1
# 1                       286                          0
# 2                       229                          0
# ...

# %%
clvd_df.tail(10)
# Out:
#      Age  Sex   Chest Pain (cp)  Resting Blood Pressure (trestbps)  \
# 293   63    1                 4                                140
# 294   63    0                 4                                124
# 295   41    1                 2                                120
# 296   59    1                 4                                164
# 297   57    0                 4                                140
# 298   45    1                 1                                110
# 299   68    1                 4                                144
# 300   57    1                 4                                130
# 301   57    0                 2                                130
# 302   38    1                 3                                138
#
#      Serum Cholestoral (Chol)  Fasting Blood Sugar (fbs)  \
# 293                       187                          0
# 294                       197                          0
# ...

# %%
clvd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Age                                                           303 non-null    int64
#  1   Sex                                                           303 non-null    int64
#  2    Chest Pain (cp)                                              303 non-null    int64
#  3   Resting Blood Pressure (trestbps)                             303 non-null    int64
#  4   Serum Cholestoral (Chol)                                      303 non-null    int64
#  5   Fasting Blood Sugar (fbs)                                     303 non-null    int64
#  6   Resting Electrocardiographic Results (restecg)                303 non-null    int64
# ...

# %%
clvd_df = clvd_df.rename(columns ={' Chest Pain (cp)':'cp',
                        'Resting Blood Pressure (trestbps)': 'trestbps',
                        'Serum Cholestoral (Chol)': 'chol',
                        'Fasting Blood Sugar (fbs)': 'fbs',
                        'Resting Electrocardiographic Results (restecg)':'restecg',
                        'Maximum Heart Rate Achieved (thalach)': 'thalach',
                        'Exercise Induced Angina (exang)':'exang',
                        'ST depression induced by exercise relative to rest (oldpeak)': 'oldpeak',
                        'the slope of the peak exercise ST segment (slope)': 'slope',
                        'number of major vessels (ca)': 'ca',
                        'diagnosis of heart disease (num)': 'num'})

# %%
clvd_df.dropna()
# Out:
#      Age  Sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   57    0   4       140   241    0        0      123      1      0.2
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
#
#      slope   ca  thal  num
# 0        3  0.0   6.0    0
# 1        2  3.0   3.0    2
# ...

# %%
va_df.head(10)
# Out:
#    Age  Sex   Chest Pain (cp)  Resting Blood Pressure (trestbps)  \
# 0   63    1                 4                              140.0
# 1   44    1                 4                              130.0
# 2   60    1                 4                              132.0
# 3   55    1                 4                              142.0
# 4   66    1                 3                              110.0
# 5   66    1                 3                              120.0
# 6   65    1                 4                              150.0
# 7   60    1                 3                              180.0
# 8   60    1                 3                              120.0
# 9   60    1                 2                              160.0
#
#    Serum Cholestoral (Chol)  Fasting Blood Sugar (fbs)  \
# 0                     260.0                        0.0
# 1                     209.0                        0.0
# 2                     218.0                        0.0
# ...

# %%
va_df.tail(10)
# Out:
#      Age  Sex   Chest Pain (cp)  Resting Blood Pressure (trestbps)  \
# 190   51    0                 4                              114.0
# 191   62    1                 4                              160.0
# 192   53    1                 4                              144.0
# 193   62    1                 4                              158.0
# 194   46    1                 4                              134.0
# 195   54    0                 4                              127.0
# 196   62    1                 1                                NaN
# 197   55    1                 4                              122.0
# 198   58    1                 4                                NaN
# 199   62    1                 2                              120.0
#
#      Serum Cholestoral (Chol)  Fasting Blood Sugar (fbs)  \
# 190                     258.0                        1.0
# 191                     254.0                        1.0
# ...

# %%
va_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Age                                                           200 non-null    int64
#  1   Sex                                                           200 non-null    int64
#  2    Chest Pain (cp)                                              200 non-null    int64
#  3   Resting Blood Pressure (trestbps)                             144 non-null    float64
#  4   Serum Cholestoral (Chol)                                      193 non-null    float64
#  5   Fasting Blood Sugar (fbs)                                     193 non-null    float64
#  6   Resting Electrocardiographic Results (restecg)                200 non-null    int64
# ...

# %%
va_df = va_df.rename(columns ={' Chest Pain (cp)':'cp',
                        'Resting Blood Pressure (trestbps)': 'trestbps',
                        'Serum Cholestoral (Chol)': 'chol',
                        'Fasting Blood Sugar (fbs)': 'fbs',
                        'Resting Electrocardiographic Results (restecg)':'restecg',
                        'Maximum Heart Rate Achieved (thalach)': 'thalach',
                        'Exercise Induced Angina (exang)':'exang',
                        'ST depression induced by exercise relative to rest (oldpeak)': 'oldpeak',
                        'the slope of the peak exercise ST segment (slope)': 'slope',
                        'number of major vessels (ca)': 'ca',
                        'diagnosis of heart disease (num)': 'num'})

# %%
va_df.dropna()
# Out:
#     Age  Sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 28   56    1   4     120.0  100.0  0.0        0    120.0    1.0      1.5
#
#    slope   ca  thal  num
# 28     2  0.0   7.0    1

# %%
hgrn_df.head(10)
# Out:
#    Age  Sex   Chest Pain (cp)  Resting Blood Pressure (trestbps)  \
# 0   40    1                 2                                140
# 1   49    0                 3                                160
# 2   37    1                 2                                130
# 3   48    0                 4                                138
# 4   54    1                 3                                150
# 5   39    1                 3                                120
# 6   45    0                 2                                130
# 7   54    1                 2                                110
# 8   37    1                 4                                140
# 9   48    0                 2                                120
#
#    Serum Cholestoral (Chol)  Fasting Blood Sugar (fbs)  \
# 0                     289.0                        0.0
# 1                     180.0                        0.0
# 2                     283.0                        0.0
# ...

# %%
hgrn_df.tail(10)
# Out:
#      Age  Sex   Chest Pain (cp)  Resting Blood Pressure (trestbps)  \
# 284   55    0                 2                                110
# 285   42    1                 4                                140
# 286   51    0                 3                                110
# 287   59    1                 4                                140
# 288   53    1                 2                                120
# 289   48    0                 2                                 -9
# 290   36    1                 2                                120
# 291   48    1                 3                                110
# 292   47    0                 2                                140
# 293   53    1                 4                                130
#
#      Serum Cholestoral (Chol)  Fasting Blood Sugar (fbs)  \
# 284                     344.0                        0.0
# 285                     358.0                        0.0
# ...

# %%
hgrn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 14 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Age                                                           294 non-null    int64
#  1   Sex                                                           294 non-null    int64
#  2    Chest Pain (cp)                                              294 non-null    int64
#  3   Resting Blood Pressure (trestbps)                             294 non-null    int64
#  4   Serum Cholestoral (Chol)                                      287 non-null    float64
#  5   Fasting Blood Sugar (fbs)                                     291 non-null    float64
#  6   Resting Electrocardiographic Results (restecg)                294 non-null    int64
# ...

# %%
hgrn_df.rename(columns ={' Chest Pain (cp)':'cp',
                        'Resting Blood Pressure (trestbps)': 'trestbps',
                        'Serum Cholestoral (Chol)': 'chol',
                        'Fasting Blood Sugar (fbs)': 'fbs',
                        'Resting Electrocardiographic Results (restecg)':'restecg',
                        'Maximum Heart Rate Achieved (thalach)': 'thalach',
                        'Exercise Induced Angina (exang)':'exang',
                        'ST depression induced by exercise relative to rest (oldpeak)': 'oldpeak',
                        'the slope of the peak exercise ST segment (slope)': 'slope',
                        'number of major vessels (ca)': 'ca',
                        'diagnosis of heart disease (num)': 'num'})
# Out:
#      Age  Sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     40    1   2       140  289.0  0.0        0      172      0      0.0
# 1     49    0   3       160  180.0  0.0        0      156      0      1.0
# 2     37    1   2       130  283.0  0.0        1       98      0      0.0
# 3     48    0   4       138  214.0  0.0        0      108      1      1.5
# 4     54    1   3       150   -9.0  0.0        0      122      0      0.0
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 289   48    0   2        -9  308.0  0.0        1       -9     -9      2.0
# 290   36    1   2       120  166.0  0.0        0      180      0      0.0
# 291   48    1   3       110  211.0  0.0        0      138      0      0.0
# 292   47    0   2       140  257.0  0.0        0      135      0      1.0
# 293   53    1   4       130  182.0  0.0        0      148      0      0.0
#
#      slope  ca  thal  num
# 0      NaN NaN   NaN    0
# ...

# %%
hgrn_df.dropna()
# Out:
# Empty DataFrame
# Columns: [Age, Sex,  Chest Pain (cp), Resting Blood Pressure (trestbps), Serum Cholestoral (Chol), Fasting Blood Sugar (fbs), Resting Electrocardiographic Results (restecg), Maximum Heart Rate Achieved (thalach), Exercise Induced Angina (exang), ST depression induced by exercise relative to rest (oldpeak), the slope of the peak exercise ST segment (slope), number of major vessels (ca), thal, diagnosis of heart disease (num)]
# Index: []
